# %%
import nfl_data_py as nfl

# %% [markdown]
# As far as I can tell this only includes offensive scoring statistics. No tackles, or pancake blocks, etc. We can read straight from the nflverse parquet files though which has defensive files available.

# %%
weekly = nfl.import_weekly_data([2024])
# Out:
# Downcasting floats.

# %%
weekly.head()
# Out:
#     player_id player_name player_display_name position position_group  \
# 0  00-0023459   A.Rodgers       Aaron Rodgers       QB             QB
# 1  00-0023459   A.Rodgers       Aaron Rodgers       QB             QB
# 2  00-0023459   A.Rodgers       Aaron Rodgers       QB             QB
# 3  00-0023459   A.Rodgers       Aaron Rodgers       QB             QB
# 4  00-0023459   A.Rodgers       Aaron Rodgers       QB             QB
#
#                                         headshot_url recent_team  season  \
# 0  https://static.www.nfl.com/image/upload/f_auto...         NYJ    2024
# 1  https://static.www.nfl.com/image/upload/f_auto...         NYJ    2024
# 2  https://static.www.nfl.com/image/upload/f_auto...         NYJ    2024
# 3  https://static.www.nfl.com/image/upload/f_auto...         NYJ    2024
# 4  https://static.www.nfl.com/image/upload/f_auto...         NYJ    2024
#
#    week season_type  ... receiving_first_downs  receiving_epa  \
# ...

# %%
weekly.columns
# Out:
# Index(['player_id', 'player_name', 'player_display_name', 'position',
#        'position_group', 'headshot_url', 'recent_team', 'season', 'week',
#        'season_type', 'opponent_team', 'completions', 'attempts',
#        'passing_yards', 'passing_tds', 'interceptions', 'sacks', 'sack_yards',
#        'sack_fumbles', 'sack_fumbles_lost', 'passing_air_yards',
#        'passing_yards_after_catch', 'passing_first_downs', 'passing_epa',
#        'passing_2pt_conversions', 'pacr', 'dakota', 'carries', 'rushing_yards',
#        'rushing_tds', 'rushing_fumbles', 'rushing_fumbles_lost',
#        'rushing_first_downs', 'rushing_epa', 'rushing_2pt_conversions',
#        'receptions', 'targets', 'receiving_yards', 'receiving_tds',
#        'receiving_fumbles', 'receiving_fumbles_lost', 'receiving_air_yards',
#        'receiving_yards_after_catch', 'receiving_first_downs', 'receiving_epa',
#        'receiving_2pt_conversions', 'racr', 'target_share', 'air_yards_share',
# ...

# %%
weekly.groupby('position_group').max()
# Out:
#                  player_id player_name  player_display_name position  \
# position_group
# DB              00-0039825    T.Thomas      Tavierre Thomas       SS
# DL              00-0034834   S.Hubbard          Sam Hubbard       DE
# LB              00-0037491   J.Russell  Jalen Reeves-Maybin      OLB
# OL              00-0039731    W.Morris         Wanya Morris        T
# QB              00-0039918     W.Levis           Will Levis       QB
# RB              00-0039921     Z.White          Zamir White       RB
# SPEC            00-0039611       T.Way            Tress Way        P
# TE              00-0039912      Z.Ertz            Zach Ertz       TE
# WR              00-0039920     Z.Jones            Zay Jones       WR
#
#                                                      headshot_url recent_team  \
# position_group
# DB              https://static.www.nfl.com/image/upload/f_auto...          TB
# DL              https://static.www.nfl.com/image/upload/f_auto...         CIN
# ...

# %%
weekly[weekly['week'] == 1]['player_name']
# Out:
# 0        A.Rodgers
# 29      M.Stafford
# 47        A.Dalton
# 53        T.Taylor
# 70       K.Cousins
#            ...
# 5489     J.Daniels
# 5514    L.McConkey
# 5546    C.Williams
# 5563      R.Odunze
# 5585      T.Benson
# Name: player_name, Length: 310, dtype: object

# %%
weekly[weekly['player_id'] =='00-0000439']
# Out:
# Empty DataFrame
# Columns: [player_id, player_name, player_display_name, position, position_group, headshot_url, recent_team, season, week, season_type, opponent_team, completions, attempts, passing_yards, passing_tds, interceptions, sacks, sack_yards, sack_fumbles, sack_fumbles_lost, passing_air_yards, passing_yards_after_catch, passing_first_downs, passing_epa, passing_2pt_conversions, pacr, dakota, carries, rushing_yards, rushing_tds, rushing_fumbles, rushing_fumbles_lost, rushing_first_downs, rushing_epa, rushing_2pt_conversions, receptions, targets, receiving_yards, receiving_tds, receiving_fumbles, receiving_fumbles_lost, receiving_air_yards, receiving_yards_after_catch, receiving_first_downs, receiving_epa, receiving_2pt_conversions, racr, target_share, air_yards_share, wopr, special_teams_tds, fantasy_points, fantasy_points_ppr]
# Index: []
#
# [0 rows x 53 columns]
