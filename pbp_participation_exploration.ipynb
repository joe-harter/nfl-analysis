# %%
import pandas as pd
from utils import get_pbp_participation_stats

pbp_participation = get_pbp_participation_stats(2023)
pbp_participation.head()
# Out:
#   nflverse_game_id old_game_id  play_id possession_team offense_formation  \
# 0  2023_01_ARI_WAS  2023091007        1                              None
# 1  2023_01_ARI_WAS  2023091007       39             ARI              None
# 2  2023_01_ARI_WAS  2023091007       55             WAS           SHOTGUN
# 3  2023_01_ARI_WAS  2023091007       77             WAS           SHOTGUN
# 4  2023_01_ARI_WAS  2023091007      102             WAS            I_FORM
#
#   offense_personnel  defenders_in_box defense_personnel  \
# 0              None               NaN              None
# 1              None               NaN              None
# 2  1 RB, 2 TE, 2 WR               7.0  3 DL, 4 LB, 4 DB
# 3  1 RB, 1 TE, 3 WR               6.0  2 DL, 4 LB, 5 DB
# 4  1 RB, 1 TE, 3 WR               6.0  2 DL, 4 LB, 5 DB
#
#    number_of_pass_rushers                                    players_on_play  \
# 0                     NaN
# ...
